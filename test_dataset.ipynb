# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('processed/master_panel.parquet')
df2 = pd.read_parquet('processed\surplus_events.parquet')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sasha\AppData\Local\Temp\ipykernel_408\1645593300.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df2 = pd.read_parquet('processed\surplus_events.parquet')

# %%
df.columns
# Out:
# Index(['datetime_utc', 'zone', 'da_price_eur_mwh', 'actual_load_mw',
#        'load_forecast_mw', 'gen_wind_onshore_mw', 'gen_wind_offshore_mw',
#        'gen_hydro_ror_mw', 'gen_hydro_reservoir_mw', 'gen_solar_mw',
#        'gen_nuclear_mw', 'gen_other_mw', 'gen_total_mw', 'exports_mw',
#        'imports_mw', 'net_export_mw', 'capacity_export_mw',
#        'capacity_import_mw', 'export_utilisation', 'import_utilisation', 't2m',
#        'wind10', 'wind100', 'msl', 'u10', 'v10', 'u100', 'v100',
#        'bal_price_down_eur_mwh', 'bal_price_up_eur_mwh',
#        'esett_production_mwh', 'esett_consumption_mwh', 'imbalance_mwh',
#        'abs_imbalance_mwh', 'hour_of_day', 'weekday', 'month', 'year',
#        'season', 'net_surplus_mw', 'renewable_gen_mw', 'renewable_share',
#        'surplus_flag', 'z_net_surplus', 'z_da_price', 'z_net_export',
#        'surplus_severity'],
#       dtype='object')
