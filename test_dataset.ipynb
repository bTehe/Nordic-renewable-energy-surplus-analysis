# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('processed/master_panel.parquet')
df2 = pd.read_parquet('processed\surplus_events.parquet')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sasha\AppData\Local\Temp\ipykernel_10136\920633512.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df2 = pd.read_parquet('processed_sample\surplus_events.parquet')

# %%
df2.head()
# Out:
#                  start_time                  end_time  duration_h  min_price  \
# 0 2023-01-01 04:00:00+00:00 2023-01-01 13:00:00+00:00          10      -0.38
# 1 2023-01-04 03:00:00+00:00 2023-01-04 03:00:00+00:00           1       0.85
# 2 2023-01-04 23:00:00+00:00 2023-01-05 03:00:00+00:00           5       0.09
# 3 2023-01-08 02:00:00+00:00 2023-01-08 02:00:00+00:00           1       4.16
# 4 2023-01-10 23:00:00+00:00 2023-01-11 04:00:00+00:00           6       0.01
#
#    mean_price  max_net_surplus_mw  mean_renewable_share  mean_wind100  \
# 0       0.143             1906.96              0.804104     14.208090
# 1       0.850             1705.52              0.900960     11.334342
# 2       0.532             1482.92              0.894946     13.378816
# 3       4.160             1973.93              0.901655      9.790168
# 4       1.340             2479.56              0.909541     14.052958
#
#    mean_load_mw  mean_net_export_mw  max_export_utilisation  \
# ...
